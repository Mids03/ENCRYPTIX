# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('archive/Churn_Modelling.csv', index_col = 0)
print(df)
# Out:
#            CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602   Hargrave          619    France  Female   42       2
# 2            15647311       Hill          608     Spain  Female   41       1
# 3            15619304       Onio          502    France  Female   42       8
# 4            15701354       Boni          699    France  Female   39       1
# 5            15737888   Mitchell          850     Spain  Female   43       2
# ...               ...        ...          ...       ...     ...  ...     ...
# 9996         15606229   Obijiaku          771    France    Male   39       5
# 9997         15569892  Johnstone          516    France    Male   35      10
# 9998         15584532        Liu          709    France  Female   36       7
# 9999         15682355  Sabbatini          772   Germany    Male   42       3
# 10000        15628319     Walker          792    France  Female   28       4
#
# ...

# %%
df.head()
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602  Hargrave          619    France  Female   42       2
# 2            15647311      Hill          608     Spain  Female   41       1
# 3            15619304      Onio          502    France  Female   42       8
# 4            15701354      Boni          699    France  Female   39       1
# 5            15737888  Mitchell          850     Spain  Female   43       2
#
#              Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber
# 1               0.00              1          1               1
# 2           83807.86              1          0               1
# 3          159660.80              3          1               0
# 4               0.00              2          0               0
# 5          125510.82              1          1               1
#
#            EstimatedSalary  Exited
# RowNumber
# 1                101348.88       1
# ...

# %%
df.shape
# Out:
# (10000, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 1 to 10000
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10000 non-null  int64
#  1   Surname          10000 non-null  object
#  2   CreditScore      10000 non-null  int64
#  3   Geography        10000 non-null  object
#  4   Gender           10000 non-null  object
#  5   Age              10000 non-null  int64
#  6   Tenure           10000 non-null  int64
#  7   Balance          10000 non-null  float64
#  8   NumOfProducts    10000 non-null  int64
#  9   HasCrCard        10000 non-null  int64
#  10  IsActiveMember   10000 non-null  int64
#  11  EstimatedSalary  10000 non-null  float64
#  12  Exited           10000 non-null  int64
# dtypes: float64(2), int64(8), object(3)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#          CustomerId   CreditScore           Age        Tenure        Balance  \
# count  1.000000e+04  10000.000000  10000.000000  10000.000000   10000.000000
# mean   1.569094e+07    650.528800     38.921800      5.012800   76485.889288
# std    7.193619e+04     96.653299     10.487806      2.892174   62397.405202
# min    1.556570e+07    350.000000     18.000000      0.000000       0.000000
# 25%    1.562853e+07    584.000000     32.000000      3.000000       0.000000
# 50%    1.569074e+07    652.000000     37.000000      5.000000   97198.540000
# 75%    1.575323e+07    718.000000     44.000000      7.000000  127644.240000
# max    1.581569e+07    850.000000     92.000000     10.000000  250898.090000
#
#        NumOfProducts    HasCrCard  IsActiveMember  EstimatedSalary  \
# count   10000.000000  10000.00000    10000.000000     10000.000000
# mean        1.530200      0.70550        0.515100    100090.239881
# std         0.581654      0.45584        0.499797     57510.492818
# ...

# %%
# Separate Data
churn = df.loc[df['Exited'] == 1]
not_churn = df.loc[df['Exited'] == 0]

# %%
churn.describe()
# Out:
#          CustomerId  CreditScore          Age       Tenure        Balance  \
# count  2.037000e+03  2037.000000  2037.000000  2037.000000    2037.000000
# mean   1.569005e+07   645.351497    44.837997     4.932744   91108.539337
# std    7.269262e+04   100.321503     9.761562     2.936106   58360.794816
# min    1.556571e+07   350.000000    18.000000     0.000000       0.000000
# 25%    1.562736e+07   578.000000    38.000000     2.000000   38340.020000
# 50%    1.568896e+07   646.000000    45.000000     5.000000  109349.290000
# 75%    1.575309e+07   716.000000    51.000000     8.000000  131433.330000
# max    1.581566e+07   850.000000    84.000000    10.000000  250898.090000
#
#        NumOfProducts    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# count    2037.000000  2037.000000     2037.000000      2037.000000  2037.0
# mean        1.475209     0.699067        0.360825    101465.677531     1.0
# std         0.801521     0.458776        0.480358     57912.418071     0.0
# ...

# %%
not_churn.describe()
# Out:
#          CustomerId  CreditScore          Age       Tenure        Balance  \
# count  7.963000e+03  7963.000000  7963.000000  7963.000000    7963.000000
# mean   1.569117e+07   651.853196    37.408389     5.033279   72745.296779
# std    7.174423e+04    95.653837    10.125363     2.880658   62848.040701
# min    1.556570e+07   405.000000    18.000000     0.000000       0.000000
# 25%    1.562882e+07   585.000000    31.000000     3.000000       0.000000
# 50%    1.569154e+07   653.000000    36.000000     5.000000   92072.680000
# 75%    1.575335e+07   718.000000    41.000000     7.000000  126410.280000
# max    1.581569e+07   850.000000    92.000000    10.000000  221532.800000
#
#        NumOfProducts    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# count    7963.000000  7963.000000     7963.000000      7963.000000  7963.0
# mean        1.544267     0.707146        0.554565     99738.391772     0.0
# std         0.509536     0.455101        0.497045     57405.586966     0.0
# ...

# %%
#Preprocessing
df.isnull().sum()
# Out:
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
numeric_cols = [col for col in df.columns if df[col].dtype != "object" and df[col].nunique() > 10 and col not in "CustomerId"]
print(numeric_cols)
# Out:
# ['CreditScore', 'Age', 'Tenure', 'Balance', 'EstimatedSalary']

# %%
# Removing Outliers
for col in numeric_cols:
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3-q1
    lower = q1 - 1.5*iqr
    upper = q3 + 1.5*iqr
    df.drop(index = np.where(df[col] >= upper)[0], inplace = True)
    df.drop(index = np.where(df[col] <= lower)[0], inplace = True)

# %%
df.shape
# Out:
# (9574, 13)

# %%
#scaling
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range = (-1,1))
for col in numeric_cols:
    df[col] = scaler.fit_transform(df[[col]])

# %%
df.drop(["CustomerId", "Surname"],axis = 1, inplace = True)
df.head()
# Out:
#            CreditScore Geography  Gender       Age  Tenure   Balance  \
# RowNumber
# 1                0.076    France  Female -0.351351    -0.6 -1.000000
# 2                0.032     Spain  Female -0.378378    -0.8 -0.331937
# 3               -0.392    France  Female -0.351351     0.6  0.272714
# 4                0.396    France  Female -0.432432    -0.8 -1.000000
# 5                1.000     Spain  Female -0.324324    -0.6  0.000492
#
#            NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# RowNumber
# 1                      1          1               1         0.013470       1
# 2                      1          0               1         0.125417       0
# 3                      3          1               0         0.139309       1
# 4                      2          0               0        -0.061760       0
# 5                      1          1               1        -0.209199       0

# %%
categorical_cols = ['Geography', 'Gender']
for col in categorical_cols:
    dummies = pd.get_dummies(df[col], drop_first=True, dtype = int)
    df = pd.concat([df, dummies], axis=1)
    df.drop(col, axis=1, inplace=True)
df.head()
# Out:
#            CreditScore       Age  Tenure   Balance  NumOfProducts  HasCrCard  \
# RowNumber
# 1                0.076 -0.351351    -0.6 -1.000000              1          1
# 2                0.032 -0.378378    -0.8 -0.331937              1          0
# 3               -0.392 -0.351351     0.6  0.272714              3          1
# 4                0.396 -0.432432    -0.8 -1.000000              2          0
# 5                1.000 -0.324324    -0.6  0.000492              1          1
#
#            IsActiveMember  EstimatedSalary  Exited  Germany  Spain  Male
# RowNumber
# 1                       1         0.013470       1        0      0     0
# 2                       1         0.125417       0        0      1     0
# 3                       0         0.139309       1        0      0     0
# 4                       0        -0.061760       0        0      0     0
# 5                       1        -0.209199       0        0      1     0

# %%
X = df.drop(['Exited'], axis = 1)
y = df['Exited'].to_numpy()
print(X)
print(y)
# Out:
#            CreditScore       Age  Tenure   Balance  NumOfProducts  HasCrCard  \
# RowNumber
# 1                0.076 -0.351351    -0.6 -1.000000              1          1
# 2                0.032 -0.378378    -0.8 -0.331937              1          0
# 3               -0.392 -0.351351     0.6  0.272714              3          1
# 4                0.396 -0.432432    -0.8 -1.000000              2          0
# 5                1.000 -0.324324    -0.6  0.000492              1          1
# ...                ...       ...     ...       ...            ...        ...
# 9996             0.684 -0.432432     0.0 -1.000000              2          1
# 9997            -0.336 -0.540541     1.0 -0.542686              1          1
# 9998             0.436 -0.513514     0.4 -1.000000              1          0
# 9999             0.688 -0.351351    -0.4 -0.401547              2          1
# 10000            0.768 -0.729730    -0.2  0.037416              1          1
#
# ...

# %%
# Splitting Data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,random_state = 42, test_size = 0.2)

# %%
# function to evaluate model
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_curve, auc

def calculate_metrics(true_labels, predicted_labels):
    accuracy = accuracy_score(true_labels, predicted_labels)
    precision = precision_score(true_labels, predicted_labels)
    recall = recall_score(true_labels, predicted_labels)
    f1_score_val = f1_score(true_labels, predicted_labels)
    confusion_matrix_val = confusion_matrix(true_labels, predicted_labels)
    
    print("Accuracy:", accuracy)
    print("Precision:", precision)
    print("Recall:", recall)
    print("F1 Score:", f1_score_val)
    print("Confusion Matrix:")
    print(confusion_matrix_val)
    
    # Plot ROC curve
    fpr, tpr, thresholds = roc_curve(true_labels, predicted_labels)
    roc_auc = auc(fpr, tpr)
    
    plt.figure()
    sns.lineplot(x = fpr, y = tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic Curve')
    plt.legend(loc="lower right")
    plt.show()

# %%
# Logistic Regression
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(random_state = 42, max_iter = 1000)
lr.fit(X_train, y_train)
lr_y_pred = lr.predict(X_test)
calculate_metrics(y_test, lr_y_pred)
# Out:
# Accuracy: 0.8130548302872063
# Precision: 0.6287878787878788
# Recall: 0.21173469387755103
# F1 Score: 0.31679389312977096
# Confusion Matrix:
# [[1474   49]
#  [ 309   83]]

# %%
# Random Forest
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(random_state = 42)
rf.fit(X_train, y_train)
rf_y_pred = rf.predict(X_test)
calculate_metrics(y_test, rf_y_pred)
# Out:
# Accuracy: 0.8610966057441253
# Precision: 0.7787610619469026
# Recall: 0.4489795918367347
# F1 Score: 0.56957928802589
# Confusion Matrix:
# [[1473   50]
#  [ 216  176]]

# %%
# Gradient Boosting
from sklearn.ensemble import GradientBoostingClassifier
gb = GradientBoostingClassifier(random_state = 42)
gb.fit(X_train, y_train)
gb_y_pred = gb.predict(X_test)
calculate_metrics(y_test, gb_y_pred)
# Out:
# Accuracy: 0.8642297650130548
# Precision: 0.7844827586206896
# Recall: 0.4642857142857143
# F1 Score: 0.5833333333333334
# Confusion Matrix:
# [[1473   50]
#  [ 210  182]]

# %%
from pycaret.regression import *
clf = setup(data = df, target = 'Exited')
# Out:
# ...
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[31], line 2
#       1 get_ipython().system('pip install pycaret')
# ----> 2 from pycaret.regression import *
#       3 clf = setup(data = df, target = 'Exited')
#
# File ~\anaconda3\Lib\site-packages\pycaret\regression\__init__.py:1
# ----> 1 from pycaret.regression.functional import (
#       2     add_metric,
#       3     automl,
#       4     blend_models,
#       5     check_drift,
#       6     check_fairness,
#       7     compare_models,
#       8     convert_model,
#       9     create_api,
#      10     create_app,
#      11     create_docker,
#      12     create_model,
#      13     dashboard,
#      14     deploy_model,
#      15     ensemble_model,
#      16     evaluate_model,
#      17     finalize_model,
#      18     get_allowed_engines,
#      19     get_config,
#      20     get_current_experiment,
# ...
